# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://www.flipkart.com/sunglasses/pr?sid=26x')

# %%
page.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/><link href="https://img1a.flixcart.com" rel="dns-prefetch"/><link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e0eee8.css"/><link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" as="image"><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon"
# ...

# %%
soup=BeautifulSoup(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
#   <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
#   <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e0eee8.css" rel="stylesheet"/>
#   <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" rel="preload"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
#    <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#    <meta content="website" property="og:type"/>
# ...

# %%
Brand=[]
price=[]
prodution=[]

# %%
Brand=soup.find_all('a',class_="IRpwTa")
Brand[0:100]
# Out:
# [<a class="IRpwTa _2-ICcC" href="/royce-wayfarer-sunglasses/p/itmfhqrktn5fjeg7?pid=SGLFHNDJGNSCWHHY&amp;lid=LSTSGLFHNDJGNSCWHHYFVMHSS&amp;marketplace=FLIPKART&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=en_ZM9L%2B6ZrfmsQz%2B2fc4XHMAy4yxRgzQVQoaCwnIuj15LgmUXe9GuyCVA%2FWqtiqQMxMMMJxQijHLOLVlu30fBBEw%3D%3D&amp;ssid=lvou8qj9800000001608127689697" rel="noopener noreferrer" target="_blank" title="UV Protection Wayfarer Sunglasses (Free Size)">UV Protection Wayfarer Sunglasses (Free Size)</a>,
# ...

# %%
price=soup.find_all('div',class_="_3I9_wc")
price[0:100]
# Out:
# [<div class="_3I9_wc">₹<!-- -->800</div>,
#  <div class="_3I9_wc">₹<!-- -->1,466</div>,
#  <div class="_3I9_wc">₹<!-- -->1,300</div>,
#  <div class="_3I9_wc">₹<!-- -->1,499</div>,
#  <div class="_3I9_wc">₹<!-- -->1,499</div>,
#  <div class="_3I9_wc">₹<!-- -->1,999</div>,
#  <div class="_3I9_wc">₹<!-- -->2,225</div>,
#  <div class="_3I9_wc">₹<!-- -->2,499</div>,
#  <div class="_3I9_wc">₹<!-- -->999</div>,
#  <div class="_3I9_wc">₹<!-- -->1,299</div>,
#  <div class="_3I9_wc">₹<!-- -->999</div>,
#  <div class="_3I9_wc">₹<!-- -->3,499</div>,
#  <div class="_3I9_wc">₹<!-- -->1,299</div>,
#  <div class="_3I9_wc">₹<!-- -->1,999</div>,
#  <div class="_3I9_wc">₹<!-- -->1,200</div>,
#  <div class="_3I9_wc">₹<!-- -->1,990</div>,
#  <div class="_3I9_wc">₹<!-- -->1,299</div>,
#  <div class="_3I9_wc">₹<!-- -->1,299</div>,
#  <div class="_3I9_wc">₹<!-- -->1,699</div>,
#  <div class="_3I9_wc">₹<!-- -->2,499</div>,
#  <div class="_3I9_wc">₹<!-- -->999</div>,
# ...

# %%
discount=soup.find_all('div',class_="_3Ay6Sb")
discount[0:100]
# Out:
# [<div class="_3Ay6Sb"><span>67% off</span></div>,
#  <div class="_3Ay6Sb"><span>88% off</span></div>,
#  <div class="_3Ay6Sb"><span>84% off</span></div>,
#  <div class="_3Ay6Sb"><span>87% off</span></div>,
#  <div class="_3Ay6Sb"><span>73% off</span></div>,
#  <div class="_3Ay6Sb"><span>80% off</span></div>,
#  <div class="_3Ay6Sb"><span>79% off</span></div>,
#  <div class="_3Ay6Sb"><span>48% off</span></div>,
#  <div class="_3Ay6Sb"><span>83% off</span></div>,
#  <div class="_3Ay6Sb"><span>87% off</span></div>,
#  <div class="_3Ay6Sb"><span>82% off</span></div>,
#  <div class="_3Ay6Sb"><span>77% off</span></div>,
#  <div class="_3Ay6Sb"><span>82% off</span></div>,
#  <div class="_3Ay6Sb"><span>80% off</span></div>,
#  <div class="_3Ay6Sb"><span>83% off</span></div>,
#  <div class="_3Ay6Sb"><span>65% off</span></div>,
#  <div class="_3Ay6Sb"><span>85% off</span></div>,
#  <div class="_3Ay6Sb"><span>75% off</span></div>,
#  <div class="_3Ay6Sb"><span>79% off</span></div>,
# ...

# %%
production=soup.find_all('div',class_="_2WkVRV")
production[0:100]
# Out:
# [<div class="_2WkVRV">Royce</div>,
#  <div class="_2WkVRV">hipe</div>,
#  <div class="_2WkVRV">FDA COLLECTION</div>,
#  <div class="_2WkVRV">FDA COLLECTION</div>,
#  <div class="_2WkVRV">Rozzetta Craft</div>,
#  <div class="_2WkVRV">Phenomenal</div>,
#  <div class="_2WkVRV">ROZZETTA CRAFT</div>,
#  <div class="_2WkVRV">ROYAL SON</div>,
#  <div class="_2WkVRV">FDA COLLECTION</div>,
#  <div class="_2WkVRV">JOHAENA</div>,
#  <div class="_2WkVRV">Winsome</div>,
#  <div class="_2WkVRV">STYLISH GUYS</div>,
#  <div class="_2WkVRV">Trendy Glasses</div>,
#  <div class="_2WkVRV">Phenomenal</div>,
#  <div class="_2WkVRV">Dannilo</div>,
#  <div class="_2WkVRV">Specsmakers</div>,
#  <div class="_2WkVRV">shadz</div>,
#  <div class="_2WkVRV">shah collections</div>,
#  <div class="_2WkVRV">shah collections</div>,
#  <div class="_2WkVRV">ROYAL SON</div>,
#  <div class="_2WkVRV">funglasses</div>,
#  <div class="_2WkVRV">Riffko</div>,
#  <div class="_2WkVRV">Fastrack</div>,
# ...

# %%
print(len(Brand),len(price),len(production))
# Out:
# 40 40 40

# %%
import pandas as pd
df=pd.DataFrame({})
df['Brand']=Brand[:100]
df['production']=production[:100]
df['price']=price[:100]

# %%
df
# Out:
#                                                 Brand          production  \
# 0     [UV Protection Wayfarer Sunglasses (Free Size)]             [Royce]
# 1   [Mirrored, UV Protection, Gradient Round Sungl...              [hipe]
# 2   [Gradient, Mirrored, UV Protection Round, Roun...    [FDA COLLECTION]
# 3   [Gradient, Mirrored, UV Protection Round, Roun...    [FDA COLLECTION]
# 4   [UV Protection Rectangular Sunglasses (Free Si...    [Rozzetta Craft]
# 5   [UV Protection, Mirrored Retro Square Sunglass...        [Phenomenal]
# 6   [UV Protection Retro Square Sunglasses (Free S...    [ROZZETTA CRAFT]
# 7                  [Polarized Sports Sunglasses (65)]         [ROYAL SON]
# 8   [Gradient, Mirrored, UV Protection, Polarized ...    [FDA COLLECTION]
# 9   [Riding Glasses, UV Protection Oval Sunglasses...           [JOHAENA]
# 10              [UV Protection Round Sunglasses (54)]           [Winsome]
# 11  [UV Protection, Mirrored, Gradient Retro Squar...      [STYLISH GUYS]
# ...
