# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://www.flipkart.com/q/shoes")

# %%
page.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/><link href="https://img1a.flixcart.com" rel="dns-prefetch"/><link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e0eee8.css"/><link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" as="image"><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon"
# ...

# %%
soup=BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
#   <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
#   <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e0eee8.css" rel="stylesheet"/>
#   <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" rel="preload"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
#    <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#    <meta content="website" property="og:type"/>
# ...

# %%
Band=[]
price=[]
discount=[]

# %%
Brand=soup.find_all('div',class_="_2WkVRV")
Brand[0:100]
# Out:
# [<div class="_2WkVRV">Nike</div>,
#  <div class="_2WkVRV">Nike</div>,
#  <div class="_2WkVRV">Aadi</div>,
#  <div class="_2WkVRV">Chevit</div>,
#  <div class="_2WkVRV">MILESWALKER</div>,
#  <div class="_2WkVRV">Asian</div>,
#  <div class="_2WkVRV">Absolute comfort</div>,
#  <div class="_2WkVRV">Sparx</div>,
#  <div class="_2WkVRV">Aadi</div>,
#  <div class="_2WkVRV">Nobelite</div>,
#  <div class="_2WkVRV">SHURAB</div>,
#  <div class="_2WkVRV">Bata</div>,
#  <div class="_2WkVRV">Aura</div>,
#  <div class="_2WkVRV">Chevit</div>,
#  <div class="_2WkVRV">Chevit</div>,
#  <div class="_2WkVRV">Naxxic</div>,
#  <div class="_2WkVRV">BRUTON</div>,
#  <div class="_2WkVRV">World Wear Footwear</div>,
#  <div class="_2WkVRV">Twin Toes</div>,
#  <div class="_2WkVRV">Sparx</div>,
#  <div class="_2WkVRV">GS</div>,
#  <div class="_2WkVRV">Marabous</div>,
#  <div class="_2WkVRV">Nobelite</div>,
#  <div class="_2WkVRV">Sparx</div>,
#  <div class="_2WkVRV">Asian</div>,
#  <div class="_2WkVRV">TR</div>,
# ...

# %%
price=soup.find_all('div',class_="_3I9_wc")
price[0:100]
# Out:
# [<div class="_3I9_wc">₹<!-- -->3,695</div>,
#  <div class="_3I9_wc">₹<!-- -->4,995</div>,
#  <div class="_3I9_wc">₹<!-- -->999</div>,
#  <div class="_3I9_wc">₹<!-- -->499</div>,
#  <div class="_3I9_wc">₹<!-- -->999</div>,
#  <div class="_3I9_wc">₹<!-- -->599</div>,
#  <div class="_3I9_wc">₹<!-- -->999</div>,
#  <div class="_3I9_wc">₹<!-- -->1,349</div>,
#  <div class="_3I9_wc">₹<!-- -->999</div>,
#  <div class="_3I9_wc">₹<!-- -->499</div>,
#  <div class="_3I9_wc">₹<!-- -->999</div>,
#  <div class="_3I9_wc">₹<!-- -->799</div>,
#  <div class="_3I9_wc">₹<!-- -->499</div>,
#  <div class="_3I9_wc">₹<!-- -->1,996</div>,
#  <div class="_3I9_wc">₹<!-- -->499</div>,
#  <div class="_3I9_wc">₹<!-- -->999</div>,
#  <div class="_3I9_wc">₹<!-- -->3,999</div>,
#  <div class="_3I9_wc">₹<!-- -->499</div>,
#  <div class="_3I9_wc">₹<!-- -->999</div>,
#  <div class="_3I9_wc">₹<!-- -->1,299</div>,
#  <div class="_3I9_wc">₹<!-- -->999</div>,
#  <div class="_3I9_wc">₹<!-- -->499</div>,
# ...

# %%
discount=soup.find_all('div',class_="_30jeq3")
discount[0:100]
# Out:
# [<div class="_30jeq3">₹2,660</div>,
#  <div class="_30jeq3">₹3,596</div>,
#  <div class="_30jeq3">₹329</div>,
#  <div class="_30jeq3">₹375</div>,
#  <div class="_30jeq3">₹339</div>,
#  <div class="_30jeq3">₹499</div>,
#  <div class="_30jeq3">₹249</div>,
#  <div class="_30jeq3">₹1,133</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹283</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹689</div>,
#  <div class="_30jeq3">₹299</div>,
#  <div class="_30jeq3">₹579</div>,
#  <div class="_30jeq3">₹273</div>,
#  <div class="_30jeq3">₹499</div>,
#  <div class="_30jeq3">₹759</div>,
#  <div class="_30jeq3">₹240</div>,
#  <div class="_30jeq3">₹348</div>,
#  <div class="_30jeq3">₹989</div>,
#  <div class="_30jeq3">₹294</div>,
#  <div class="_30jeq3">₹375</div>,
#  <div class="_30jeq3">₹398</div>,
#  <div class="_30jeq3">₹1,199</div>,
#  <div class="_30jeq3">₹699</div>,
#  <div class="_30jeq3">₹329</div>,
#  <div class="_30jeq3">₹399</div>,
# ...

# %%
print(len(Brand),len(price),len(discount))
# Out:
# 40 40 45

# %%
import pandas as pd
df=pd.DataFrame({})
df['Brand']=Brand[:40]
df['price']=price[:40]
df['discount']=discount[:40]

# %%
df
# Out:
#                     Brand          price  discount
# 0                  [Nike]  [₹,  , 3,695]  [₹2,660]
# 1                  [Nike]  [₹,  , 4,995]  [₹3,596]
# 2                  [Aadi]    [₹,  , 999]    [₹329]
# 3                [Chevit]    [₹,  , 499]    [₹375]
# 4           [MILESWALKER]    [₹,  , 999]    [₹339]
# 5                 [Asian]    [₹,  , 599]    [₹499]
# 6      [Absolute comfort]    [₹,  , 999]    [₹249]
# 7                 [Sparx]  [₹,  , 1,349]  [₹1,133]
# 8                  [Aadi]    [₹,  , 999]    [₹399]
# 9              [Nobelite]    [₹,  , 499]    [₹283]
# 10               [SHURAB]    [₹,  , 999]    [₹399]
# 11                 [Bata]    [₹,  , 799]    [₹689]
# 12                 [Aura]    [₹,  , 499]    [₹299]
# 13               [Chevit]  [₹,  , 1,996]    [₹579]
# 14               [Chevit]    [₹,  , 499]    [₹273]
# 15               [Naxxic]    [₹,  , 999]    [₹499]
# 16               [BRUTON]  [₹,  , 3,999]    [₹759]
# ...
